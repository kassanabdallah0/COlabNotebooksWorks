# %%
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

# %% [markdown]
# ### Create Data

# %% [markdown]
# create:
# * noisy_images with lines as an input_train
# * noisy_images with out lines as an output_train

# %%
from numpy.random import default_rng
import skimage.exposure

def random_quadrillage_generator(indice=1, width=500, height=500, sigmaX=10, sigmaY=10, thresh=200, blur=11, path='/content/quadrillage'):
  # define random seed to change the pattern
  rng = default_rng()
  # create random noise image
  noise = rng.integers(0, 255, (height,width), np.uint8, True)

  # blur the noise image to control the size
  blur = cv2.GaussianBlur(noise, (blur,blur), sigmaX, sigmaY, borderType = cv2.BORDER_DEFAULT)

  # stretch the blurred image to full dynamic range
  stretch = skimage.exposure.rescale_intensity(blur, in_range='image', out_range=(0,255)).astype(np.uint8)

  # threshold stretched image to control the size
  thresh = cv2.threshold(stretch, thresh, 255, cv2.THRESH_BINARY)[1]
  # apply morphology open and close to smooth out shapes
  kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3,3))
  result = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel)
  result = cv2.morphologyEx(result, cv2.MORPH_CLOSE, kernel)
  horizantal = np.random.randint(4, 15)
  verticale = np.random.randint(4, 15)
  result_noise = np.zeros(result.shape, np.uint8)
  result_noise += result
  for i in range (1, horizantal + 1):
    fact = np.random.randint(50, 100)
    ponte = np.random.randint(10, 20)
    #fact = 50
    h = 99 + i*ponte + fact
    cv2.line(result, (100,h), (400,h), (255,0,0), 2)
  for i in range(1, verticale + 1):
    fact = np.random.randint(50, 100)
    ponte = np.random.randint(10, 20)
    v = 119 + i*ponte + fact
    cv2.line(result, (v,100), (v,400), (255,0,0), 2)

  guess = np.random.randint(0, 1)
  if guess == 0:
    # Rotation
    rot = np.random.randint(-15, 15)
    (h, w) = result.shape[:2]
    center = (w / 2, h / 2)
    angle = rot
    scale = 1

    M = cv2.getRotationMatrix2D(center, angle, scale)
    result= cv2.warpAffine(result, M, (w, h))
    result_noise = cv2.warpAffine(result_noise, M, (w, h))
   # save result
  cv2.imwrite('/content/quadrillage/input_train/'f'{indice}_{indice}.jpg', result)
  cv2.imwrite('/content/quadrillage/target_train/'f'{indice}_{indice}.jpg', result_noise)

# %%
'''
for i in range(1, 60000):
  width = np.random.randint(200, 800)
  height = np.random.randint(200, 800)
  sigmaX = np.random.randint(10, 15)
  sigmaY = np.random.randint(10, 15)
  thresh = np.random.randint(180, 210)
  while True:
    blur = np.random.randint(11,15)
    if not blur%2 == 0:
      break
  random_quadrillage_generator(i, width=width, height=height, sigmaX=sigmaX, sigmaY=sigmaY, thresh=thresh, blur=blur)
  if i == 59999:
    print('Done')
'''
# Out:
# Done

# %% [markdown]
# create:
# * noisy_images with lines as an input_test
# * noisy_images with out lines as an output_test

# %%
def random_quadrillage_generator(indice=1, width=500, height=500, sigmaX=10, sigmaY=10, thresh=200, blur=11, path='/content/quadrillage'):
  # define random seed to change the pattern
  rng = default_rng()
  # create random noise image
  noise = rng.integers(0, 255, (height,width), np.uint8, True)

  # blur the noise image to control the size
  blur = cv2.GaussianBlur(noise, (blur,blur), sigmaX, sigmaY, borderType = cv2.BORDER_DEFAULT)

  # stretch the blurred image to full dynamic range
  stretch = skimage.exposure.rescale_intensity(blur, in_range='image', out_range=(0,255)).astype(np.uint8)

  # threshold stretched image to control the size
  thresh = cv2.threshold(stretch, thresh, 255, cv2.THRESH_BINARY)[1]
  # apply morphology open and close to smooth out shapes
  kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3,3))
  result = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel)
  result = cv2.morphologyEx(result, cv2.MORPH_CLOSE, kernel)
  horizantal = np.random.randint(4, 15)
  verticale = np.random.randint(4, 15)
  result_noise = np.zeros(result.shape, np.uint8)
  result_noise += result
  for i in range (1, horizantal + 1):
    fact = np.random.randint(50, 100)
    ponte = np.random.randint(10, 20)
    #fact = 50
    h = 99 + i*ponte + fact
    cv2.line(result, (100,h), (400,h), (255,0,0), 2)
  for i in range(1, verticale + 1):
    fact = np.random.randint(50, 100)
    ponte = np.random.randint(10, 20)
    v = 119 + i*ponte + fact
    cv2.line(result, (v,100), (v,400), (255,0,0), 2)

  guess = np.random.randint(0, 1)
  if guess == 0:
    # Rotation
    rot = np.random.randint(-15, 15)
    (h, w) = result.shape[:2]
    center = (w / 2, h / 2)
    angle = rot
    scale = 1

    M = cv2.getRotationMatrix2D(center, angle, scale)
    result= cv2.warpAffine(result, M, (w, h))
    result_noise = cv2.warpAffine(result_noise, M, (w, h))
   # save result
  cv2.imwrite('/content/quadrillage/input_test/'f'{indice}_{indice}.jpg', result)
  cv2.imwrite('/content/quadrillage/target_test/'f'{indice}_{indice}.jpg', result_noise)

# %%
'''
for i in range(1, 1000):
  width = np.random.randint(200, 800)
  height = np.random.randint(200, 800)
  sigmaX = np.random.randint(10, 15)
  sigmaY = np.random.randint(10, 15)
  thresh = np.random.randint(180, 210)
  while True:
    blur = np.random.randint(11,15)
    if not blur%2 == 0:
      break
  random_quadrillage_generator(i, width=width, height=height, sigmaX=sigmaX, sigmaY=sigmaY, thresh=thresh, blur=blur)
  if i == 999:
    print('Done')
'''
# Out:
# Done

# %% [markdown]
# Create our datasets for training

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

# %%
'''
import zipfile
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/quadrillage_dataset.zip", 'r')
zip_ref.extractall("/content/quadrillage")
zip_ref.close()
'''
# Out:
# '\nimport zipfile\nzip_ref = zipfile.ZipFile("/content/drive/MyDrive/quadrillage_dataset.zip", \'r\')\nzip_ref.extractall("/content/quadrillage")\nzip_ref.close()\n'

# %%
batch_size = 150
no_epochs = 50
validation_split = 0.2
verbosity = 1
max_norm_value = 2.0
noise_factor = 0.55
number_of_visualizations = 6

# %%
#input_train = np.load("/content/quadrillage/quadrillage_dataset/input_train/input_train.npy")
input_test = np.load("/content/quadrillage/quadrillage_dataset/input_test/input_test.npy")
#target_train = np.load("/content/quadrillage/quadrillage_dataset/target_train/target_train.npy")
target_test = np.load("/content/quadrillage/quadrillage_dataset/target_test/target_test.npy")

# %%
input_train_1 = np.split(input_train, 2)

# %%
input_tr = np.array(input_train_1[0])

# %%
'''
with open('half_input_train.npy', 'wb') as f:
  np.save(f, input_tr)
'''
# Out:
# "\nwith open('half_input_train.npy', 'wb') as f:\n  np.save(f, input_tr)\n"

# %%
'''
target_train_1 = np.split(target_train, 3)
target_tr = np.array(target_train_1[0])
with open('half_target_train.npy', 'wb') as f:
  np.save(f, target_tr)
'''
# Out:
# "\ntarget_train_1 = np.split(target_train, 3)\ntarget_tr = np.array(target_train_1[0])\nwith open('half_target_train.npy', 'wb') as f:\n  np.save(f, target_tr)\n"

# %%
input_train = np.load("/content/half_input_train.npy")
target_train = np.load("/content/half_target_train.npy")

# %%
input_train.shape, target_train.shape, input_test.shape, target_test.shape
# Out:
# ((20000, 128, 128), (20000, 128, 128), (1000, 128, 128), (1000, 128, 128))

# %% [markdown]
# ### Create the model

# %%
img_width = 128
img_height = 128
input_train = input_train.reshape(input_train.shape[0], img_width, img_height, 1)
input_test = input_test.reshape(input_test.shape[0], img_width, img_height, 1)
input_shape = (img_width, img_height, 1)

# Parse numbers as floats
input_train = input_train.astype('float32')
input_test = input_test.astype('float32')

# Normalize data
input_train = input_train / 255
input_test = input_test / 255

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Dropout, Dense
from keras.constraints import max_norm
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
model = Sequential()
#Encoder
model.add(Conv2D(128, kernel_size=(3, 3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform', input_shape=input_shape))
model.add(Conv2D(64, kernel_size=(3, 3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(32, kernel_size=(3, 3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform'))
model.add(Conv2D(32, kernel_size=(3, 3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform'))
model.add(Dropout(.2))
#Decoder
model.add(Conv2DTranspose(32, kernel_size=(3,3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2DTranspose(32, kernel_size=(3,3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2DTranspose(64, kernel_size=(3,3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2DTranspose(64, kernel_size=(3,3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform'))
model.add(Dropout(.2))
model.add(Conv2D(1, kernel_size=(3, 3), kernel_constraint=max_norm(max_norm_value), activation='sigmoid', padding='same'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 126, 126, 128)     1280
#
#  conv2d_1 (Conv2D)           (None, 124, 124, 64)      73792
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 32)        18464
#
#  conv2d_3 (Conv2D)           (None, 58, 58, 32)        9248
#
#  dropout (Dropout)           (None, 58, 58, 32)        0
#
#  conv2d_transpose (Conv2DTra  (None, 60, 60, 32)       9248
#  nspose)
#
#  up_sampling2d (UpSampling2D  (None, 120, 120, 32)     0
#  )
#
#  conv2d_transpose_1 (Conv2DT  (None, 122, 122, 32)     9248
#  ranspose)
#
#  max_pooling2d_1 (MaxPooling  (None, 61, 61, 32)       0
#  2D)
#
#  conv2d_transpose_2 (Conv2DT  (None, 63, 63, 64)       18496
#  ranspose)
#
#  up_sampling2d_1 (UpSampling  (None, 126, 126, 64)     0
#  2D)
#
# ...

# %%
import time

# %%
step = len(input_train)//batch_size
val_step = (len(input_train)*0.2//batch_size)

# %%
BeginTime = int(round(time.time() * 1000))
model.compile(optimizer="adam", loss="binary_crossentropy")
history = model.fit(
    x=input_train,
    y=target_train,
    epochs=50,
    batch_size=128,
    shuffle=True,
    validation_split=0.2,
)
EndTime = int(round(time.time() * 1000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c31ec8d7cc96> in <module>()
# ----> 1 BeginTime = int(round(time.time() * 1000))
#       2 model.compile(optimizer="adam", loss="binary_crossentropy")
#       3 history = model.fit(
#       4     x=input_train,
#       5     y=target_train,
#
# NameError: name 'time' is not defined

# %%
print(EndTime)

# %%
model.save('modelquad_autoencoder_denoising.h5')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(30)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
