# %%
! pip install -U -f https://extras.wxpython.org/wxPython4/extras/linux/gtk3/ubuntu-18.04/ wxPython
# Out:
# Looking in links: https://extras.wxpython.org/wxPython4/extras/linux/gtk3/ubuntu-18.04/
# Requirement already satisfied: wxPython in /usr/local/lib/python3.7/dist-packages (4.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wxPython) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from wxPython) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from wxPython) (1.15.0)

# %%
import wx

app = wx.App()
frame = wx.Frame(parent=None, title='Hello World')
frame.Show()
app.MainLoop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-0080cd6677f0> in <module>()
# ----> 1 from wxpython import wx
#       2
#       3 app = wx.App()
#       4 frame = wx.Frame(parent=None, title='Hello World')
#       5 frame.Show()
#
# ModuleNotFoundError: No module named 'wxpython'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
